# %%
import matplotlib.pyplot as plt
import cv2 as cv

algo = 'MOG2'
path = 'data/panoptic-toolbox/160401_ian3/hdImgs_unditorted/00_00/00_00_00000000.jpg'

if algo == 'MOG2':
    backSub = cv.createBackgroundSubtractorMOG2()
else:
    backSub = cv.createBackgroundSubtractorKNN()
 
capture = cv.VideoCapture(cv.samples.findFileOrKeep(path))
# Out:
# [ WARN:0@218.629] global samples.cpp:61 findFile cv::samples::findFile('data/panoptic-toolbox/160401_ian3/hdImgs_unditorted/00_00/00_00_00000000.jpg') => ''

# %%
while True:
    ret, frame = capture.read()
    if frame is None:
        break

    fgMask = backSub.apply(frame)


    cv.rectangle(frame, (10, 2), (100,20), (255,255,255), -1)
    cv.putText(frame, str(capture.get(cv.CAP_PROP_POS_FRAMES)), (15, 15),
    cv.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0))


    # cv.imshow('Frame', frame)
    # cv.imshow('FG Mask', fgMask)

# %%
plt.imshow(fgMask)
